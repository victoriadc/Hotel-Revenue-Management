# %% [markdown]
# # Hotel Reservations Dataset

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV

import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
sys.path.insert(0, 'C:/Users/viqui/Documents/AW Data Science/_functions_')

from Functions_EDA import *
from fx_MLRegression import *
from fx_MLClassification import *
pd.options.display.max_columns = None
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# Note: personal data has been removed in a different notebook

# %%
df = pd.read_csv('datasets/bookings201731_2022228_nodata.csv', index_col = 0)
df
# Out:
#           Number                            Channel    Check in   Check out  \
# 0     1133853485                    Booking.com XML  2017-04-08  2017-04-09
# 1     1189403050                    Booking.com XML  2017-04-08  2017-04-09
# 2     1868347451                    Booking.com XML  2017-04-08  2017-04-09
# 3     1426867077                    Booking.com XML  2017-04-07  2017-04-09
# 4      793922993                        Expedia XML  2017-04-07  2017-04-09
# ..           ...                                ...         ...         ...
# 623       548378  RoomCloud  BE & Metasearch Engine  2021-12-31  2022-01-08
# 624       548650  RoomCloud  BE & Metasearch Engine  2021-12-31  2022-01-05
# 625  16575247102                  Despegar PAM2 XML  2021-12-31  2022-01-01
# 626   3437392605                    Booking.com XML  2021-12-31  2022-01-02
# 627  16719062902                  Despegar PAM2 XML  2021-12-31  2022-01-01
#
#                                Rooms  Persons  Adults  Children   Total  \
# 0                        1 TPL Twin         3       3         0   79.34
# 1                         1 DBL Mat         2       2         0   83.97
# 2                         1 DBL Mat         2       2         0   97.19
# 3                         1 DBL Mat         2       2         0  113.82
# 4                        1 DBL Twin         2       2         0  110.16
# ..                               ...      ...     ...       ...     ...
# 623  1 Habitación Doble Matrimonial         2       2         0  308.60
# 624  1 Habitación Doble Matrimonial         2       2         0  200.75
# 625                           1 SGL         1       1         0   47.89
# 626      1 DBL Twin 1 SGL 1 DBL Mat         5       5         0  414.54
# 627                       1 DBL Mat         2       2         0   54.46
#
#      Commission  Prepaid    Country  Reservation Date  \
# 0         14.28     0.00  Argentina  2017-03-15 12:25
# 1         15.11     0.00  Argentina  2017-03-30 22:50
# 2         17.49     0.00  Argentina  2017-04-07 20:36
# 3         20.49     0.00    Uruguay  2017-01-27 14:34
# 4          0.00   110.16        NaN  2017-02-14 22:27
# ..          ...      ...        ...               ...
# 623        0.00     0.00      Chile  2021-11-08 17:40
# 624        0.00     0.00      Chile  2021-11-09 11:18
# 625        0.00     0.00  Argentina  2021-12-05 22:24
# 626       74.62     0.00  Argentina  2021-12-22 19:59
# 627        0.00     0.00  Argentina  2021-12-23 16:40
#
#     Date of creation or modification Cancellation Date       Payment  \
# 0                   2017-03-17 01:07   2017-03-17 01:07  Credit card
# 1                   2017-03-30 22:50                NaN  Credit card
# 2                   2017-04-07 20:36                NaN  Credit card
# 3                   2017-02-27 09:06   2017-02-27 09:06  Credit card
# 4                   2017-02-14 22:28                NaN  Credit card
# ..                               ...                ...          ...
# 623                 2021-11-08 17:40                NaN         Cash
# 624                 2021-11-09 11:18                NaN         Cash
# 625                 2021-12-05 22:24                NaN  Credit card
# 626                 2021-12-22 23:09   2021-12-22 23:08  Credit card
# 627                 2021-12-23 16:40                NaN  Credit card
#
#        Status
# 0    Cancelled
# 1          New
# 2          New
# 3    Cancelled
# 4          New
# ..         ...
# 623        New
# 624        New
# 625        New
# 626  Cancelled
# 627        New
#
# [14174 rows x 17 columns]

# %%
df.columns
# Out:
# Index(['Number', 'Channel', 'Check in', 'Check out', 'Rooms', 'Persons',
#        'Adults', 'Children', 'Total', 'Commission', 'Prepaid', 'Country',
#        'Reservation Date', 'Date of creation or modification',
#        'Cancellation Date ', 'Payment', 'Status '],
#       dtype='object')

# %%
percentage_nullValues(df)
# Out:
#                                   Percentage_NaN
# Cancellation Date                           80.9
# Country                                     18.8
# Payment                                      9.6
# Number                                       0.0
# Commission                                   0.0
# Date of creation or modification             0.0
# Reservation Date                             0.0
# Prepaid                                      0.0
# Total                                        0.0
# Channel                                      0.0
# Children                                     0.0
# Adults                                       0.0
# Persons                                      0.0
# Rooms                                        0.0
# Check out                                    0.0
# Check in                                     0.0
# Status                                       0.0

# %%
df.describe().T
# Out:
#               count        mean         std  min      25%      50%       75%  \
# Persons     14174.0    1.947439    1.094615  1.0   1.0000    2.000    2.0000
# Adults      14174.0    1.910470    1.074695  1.0   1.0000    2.000    2.0000
# Children    14174.0    0.036969    0.216876  0.0   0.0000    0.000    0.0000
# Total       14174.0  182.740648  200.826827  0.0  60.7675  125.335  232.0425
# Commission  14174.0   24.802843   52.007409  0.0   0.0000   11.660   33.0400
# Prepaid     14174.0   37.193914   94.344926  0.0   0.0000    0.000    0.0000
#
#                 max
# Persons       44.00
# Adults        44.00
# Children       5.00
# Total       6498.44
# Commission  2997.00
# Prepaid     1668.70

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14174 entries, 0 to 627
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Number                            14174 non-null  object
#  1   Channel                           14174 non-null  object
#  2   Check in                          14174 non-null  object
#  3   Check out                         14174 non-null  object
#  4   Rooms                             14174 non-null  object
#  5   Persons                           14174 non-null  int64
#  6   Adults                            14174 non-null  int64
#  7   Children                          14174 non-null  int64
#  8   Total                             14174 non-null  float64
#  9   Commission                        14174 non-null  float64
#  10  Prepaid                           14174 non-null  float64
#  11  Country                           11513 non-null  object
#  12  Reservation Date                  14174 non-null  object
#  13  Date of creation or modification  14174 non-null  object
#  14  Cancellation Date                 2713 non-null   object
#  15  Payment                           12819 non-null  object
#  16  Status                            14174 non-null  object
# dtypes: float64(3), int64(3), object(11)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Cleaning

# %%
#Changing type of 5 variables to datetime
import datetime as dt
df['Check in'] = pd.to_datetime(df['Check in'], format = '%Y.%m.%d')
df['Check out'] = pd.to_datetime(df['Check out'], format = '%Y.%m.%d')
df['Reservation Date'] = pd.to_datetime(df['Reservation Date'], format='%Y.%m.%d')
df['Date of creation or modification'] = pd.to_datetime(df['Date of creation or modification'], format='%Y.%m.%d')
df['Cancellation Date '] = pd.to_datetime(df['Cancellation Date '], format='%Y.%m.%d')

# %%
df.head()
# Out:
#        Number          Channel   Check in  Check out        Rooms  Persons  \
# 0  1133853485  Booking.com XML 2017-04-08 2017-04-09  1 TPL Twin         3
# 1  1189403050  Booking.com XML 2017-04-08 2017-04-09   1 DBL Mat         2
# 2  1868347451  Booking.com XML 2017-04-08 2017-04-09   1 DBL Mat         2
# 3  1426867077  Booking.com XML 2017-04-07 2017-04-09   1 DBL Mat         2
# 4   793922993      Expedia XML 2017-04-07 2017-04-09  1 DBL Twin         2
#
#    Adults  Children   Total  Commission  Prepaid    Country  \
# 0       3         0   79.34       14.28     0.00  Argentina
# 1       2         0   83.97       15.11     0.00  Argentina
# 2       2         0   97.19       17.49     0.00  Argentina
# 3       2         0  113.82       20.49     0.00    Uruguay
# 4       2         0  110.16        0.00   110.16        NaN
#
#      Reservation Date Date of creation or modification  Cancellation Date   \
# 0 2017-03-15 12:25:00              2017-03-17 01:07:00 2017-03-17 01:07:00
# 1 2017-03-30 22:50:00              2017-03-30 22:50:00                 NaT
# 2 2017-04-07 20:36:00              2017-04-07 20:36:00                 NaT
# 3 2017-01-27 14:34:00              2017-02-27 09:06:00 2017-02-27 09:06:00
# 4 2017-02-14 22:27:00              2017-02-14 22:28:00                 NaT
#
#        Payment    Status
# 0  Credit card  Cancelled
# 1  Credit card        New
# 2  Credit card        New
# 3  Credit card  Cancelled
# 4  Credit card        New

# %%
find_categorical_uniques(df)
# Out:
# Channel : ['Booking.com XML' 'Expedia XML' 'Despegar PAM2 XML' 'Airbnb'
#  'RoomCloud  BE & Metasearch Engine' 'Hotelbeds XML' 'BestDay XML'
#  'HotelyPago XML (Argenway)']
# ====================================
#
# Payment : ['Credit card' nan 'Transfer' 'Cash']
# ====================================
#
# Status  : ['Cancelled' 'New' 'Modified' 'Rejected' 'No show']
# ====================================
# ['Channel', 'Payment', 'Status ']

# %%
# Getting rid of rejected and cancelled bookings
df = df[(df['Status '] != 'Rejected')  | (df['Status '] != 'Cancelled')]

# %%
df[df.Payment.isna()]
#Will keep this rows as there is no clear indication as why payment is Nan
# Out:
#          Number            Channel   Check in  Check out        Rooms  \
# 82   1257479491    Booking.com XML 2017-03-31 2017-04-01   1 DBL Mat
# 85   3396415402  Despegar PAM2 XML 2017-03-30 2017-04-05       1 SGL
# 118  2054636820    Booking.com XML 2017-03-28 2017-03-29       1 SGL
# 119  1951469076    Booking.com XML 2017-03-28 2017-03-30       1 SGL
# 140  1659735387    Booking.com XML 2017-03-26 2017-03-27       1 SGL
# ..          ...                ...        ...        ...          ...
# 592  75424316-1        BestDay XML 2022-01-06 2022-01-07   1 DBL Mat
# 597  1877449683        Expedia XML 2022-01-05 2022-01-06   1 DBL Mat
# 598  2742612123    Booking.com XML 2022-01-05 2022-01-06  1 DBL Twin
# 599  3345616287    Booking.com XML 2022-01-05 2022-01-06       1 SGL
# 605  3909653888    Booking.com XML 2022-01-04 2022-01-05   1 DBL Mat
#
#      Persons  Adults  Children   Total  Commission  Prepaid    Country  \
# 82         2       2         0  110.42       19.88     0.00  Argentina
# 85         1       1         0  243.31        0.00   243.31        NaN
# 118        1       1         0   50.25        9.04     0.00  Argentina
# 119        1       1         0  107.11       19.28     0.00  Argentina
# 140        1       1         0   51.17        9.21     0.00  Argentina
# ..       ...     ...       ...     ...         ...      ...        ...
# 592        2       2         0   46.10        0.00    46.10  Argentina
# 597        1       1         0   37.04        0.00     0.00        NaN
# 598        2       2         0   48.98        7.29     0.00  Argentina
# 599        1       1         0   44.39        6.60     0.00  Argentina
# 605        2       2         0   51.87        7.72     0.00  Argentina
#
#        Reservation Date Date of creation or modification Cancellation Date   \
# 82  2017-04-01 00:27:00              2017-04-01 00:27:00                NaT
# 85  2017-03-15 15:14:00              2017-03-15 15:20:00                NaT
# 118 2017-03-28 23:03:00              2017-03-28 23:03:00                NaT
# 119 2017-03-28 23:13:00              2017-03-28 23:13:00                NaT
# 140 2017-03-26 18:31:00              2017-03-26 18:32:00                NaT
# ..                  ...                              ...                ...
# 592 2022-01-04 16:17:00              2022-01-04 15:25:00                NaT
# 597 2022-01-05 07:07:00              2022-01-05 07:07:00                NaT
# 598 2022-01-05 12:07:00              2022-01-05 12:08:00                NaT
# 599 2022-01-05 13:44:00              2022-01-05 13:45:00                NaT
# 605 2022-01-04 01:10:00              2022-01-04 01:11:00                NaT
#
#     Payment Status
# 82      NaN     New
# 85      NaN     New
# 118     NaN     New
# 119     NaN     New
# 140     NaN     New
# ..      ...     ...
# 592     NaN     New
# 597     NaN     New
# 598     NaN     New
# 599     NaN     New
# 605     NaN     New
#
# [1355 rows x 17 columns]

# %%
# Dropping rows of outliers (bookings for 10 or more ppl)
df.drop(df[df['Persons'] >= 10].index, inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (13659, 17)

# %% [markdown]
# ### Making all prices Net prices
# - In this df, Total prices sometimes include the commission and sometimes not, depending on the Channel.
# - Creating a new column 'Net' with all **real** net values. This has to be calculated channel by channel as the rules are different.
# - Some Channels consider Total as Net, so setting that as default

# %%
df['Net'] = df['Total']

# %%
df.Channel.value_counts(normalize=True)*100
# Out:
# Booking.com XML                      65.261000
# Expedia XML                          15.228055
# RoomCloud  BE & Metasearch Engine     9.554140
# Despegar PAM2 XML                     6.669595
# Hotelbeds XML                         2.723479
# BestDay XML                           0.314811
# HotelyPago XML (Argenway)             0.168387
# Airbnb                                0.080533
# Name: Channel, dtype: float64

# %%
# BOOKING -> Total is Commission + Net, commission equals 18%
df.loc[df.Channel == 'Booking.com XML', 'Net'] = df.loc[df.Channel == 'Booking.com XML', 'Total' ] * 0.82

# %%
# EXPEDIA: this channel's Net price depends on Prepaid variable   
#         -> if Prepaid != 0, Total is actually Net ☑
#         -> if Prepaid ==0, Net is Total*0.8 (commission 20%)

df.loc[(df.Channel == 'Expedia XML') & (df.Prepaid == 0), 'Net'] = df.loc[(df.Channel == 'Expedia XML' ) & (df.Prepaid == 0), 'Total' ] * 0.8

# %%
#ROOMCLOUD -> Total is actually Net ☑

#DESPEGAR -> Total is actually Net  ☑

#HOTELBEDS -> Net is Total * 0.75
df.loc[df.Channel == 'Hotelbeds XML', 'Net'] = df.loc[df.Channel == 'Hotelbeds XML', 'Total' ] * 0.75

#BESTDAY -> Net is Total * 0.79
df.loc[df.Channel == 'BestDay XML', 'Net'] = df.loc[df.Channel == 'BestDay XML', 'Total' ] * 0.79

#HotelyPago XML (Argenway) -> Total is Net ☑

#AIRBNB -> removing it
df.drop(df[df['Channel'] == 'Airbnb'].index, inplace = True)

# %%
df.shape
# Out:
# (13410, 18)

# %% [markdown]
# ### Cleaning room types
# The types of rooms that this hotel has are:
#
# - '1 SGL '
#
# - '1 DBL Mat '
# - '1 DBL Twin '
#
# - '1 TPL Mat '
# - '1 TPL Twin '
#
# - '1 SUP '
#
# Pricewise, the types of rooms are only 4: 1 SGL, 1 DBL, 1 TPL and 1 SUP

# %%
df.Rooms.value_counts()
# Out:
# 1 DBL Mat                                                      5075
# 1 SGL                                                          3178
# 1 DBL Twin                                                     1638
# 1 TPL Mat                                                       705
# 1 Habitación Doble Matrimonial                                  519
#                                                                ...
# 1 DBL Mat 1 TPL Twin 1 TPL Twin                                   1
# 1 Habitación Doble Matrimonial 1 Habitación Doble Superior        1
# 1 TPL Mat 1 SGL 1 SGL                                             1
# 1 SGL 1 DBL Mat 1 SGL                                             1
# 1 DBL Twin 1 SGL 1 DBL Mat                                        1
# Name: Rooms, Length: 154, dtype: int64

# %%
# 1: removing extra spaces
df.Rooms = df.Rooms.str.rstrip()

# %%
# 2: Standardizing room names

rooms_map = { '1 Habitación Doble Matrimonial' : '1 DBL Mat', 
              '1 Single' : '1 SGL', 
              '1 Habitación Doble - 2 camas' : '1 DBL Mat',
              '1 Habitación Triple Matrimonial' : '1 TPL Mat',
              '1 Standard Double Room' : '1 DBL Mat',
            '1 Habitación Triple Twin (3 camas)' : '1 TPL Twin',
            '1 Habitación Doble Superior' : '1 SUP',
            '1 Single Room' : '1 SGL',
            '2 Habitación Doble Matrimonial' : '1 DBL Mat 1 DBL Mat',
            '1 Superior Double Room' : '1 SUP',
            '1 Standard Twin Room' : '1 DBL Twin',
            '1 DOBLE MAT' : '1 DBL Mat',
            '2 Single': '1 SGL 1 SGL',
            '2 Habitación Doble - 2 camas' : '1 DBL Twin 1 DBL Twin',
            '1 Habitación Doble Matrimonial 1 Habitación Doble - 2 camas' : '1 DBL Mat 1 DBL Twin',
            '1 Standard Triple Room' : '1 TPL Mat',
            '2 DBL Mat': '1 DBL Mat 1 DBL Mat',
            '1 Camera Tripla Standard': '1 TPL Mat',
            '2 Standard Twin Room': '1 DBL Twin 1 DBL Twin',
             '2 Standard Twin Room ': '1 DBL Twin 1 DBL Twin',
            '2 Standard Double Room' : '1 DBL Mat 1 DBL Mat'}

# %%
df.Rooms.value_counts().head(19)
# Out:
# 1 DBL Mat                             5075
# 1 SGL                                 3178
# 1 DBL Twin                            1638
# 1 TPL Mat                              705
# 1 Habitación Doble Matrimonial         519
# 1 TPL Twin                             410
# 1 SUP                                  291
# 1 Single                               286
# 1 DBL Mat 1 DBL Mat                    165
# 1 Habitación Doble - 2 camas           139
# 1 SGL 1 SGL                             90
# 1 Habitación Triple Matrimonial         65
# 1 DBL Twin 1 DBL Twin                   59
# 1 Standard Double Room                  57
# 1 Habitación Triple Twin (3 camas)      44
# 1 Habitación Doble Superior             32
# 1 DBL Twin 1 DBL Mat                    31
# 1 Single Room                           30
# 1 DBL Mat 1 DBL Twin                    30
# Name: Rooms, dtype: int64

# %%
df.shape
# Out:
# (13410, 18)

# %%
df = df.replace({'Rooms' : rooms_map})
df.Rooms.value_counts().head(19)
# Out:
# 1 DBL Mat                5799
# 1 SGL                    3494
# 1 DBL Twin               1647
# 1 TPL Mat                 780
# 1 TPL Twin                454
# 1 SUP                     335
# 1 DBL Mat 1 DBL Mat       198
# 1 SGL 1 SGL                98
# 1 DBL Twin 1 DBL Twin      69
# 1 DBL Mat 1 DBL Twin       36
# 1 DBL Twin 1 DBL Mat       31
# 1 DBL Mat 1 TPL Mat        29
# 1 DBL Mat 1 TPL Twin       27
# 1 SGL 1 DBL Mat            27
# 1 TPL Mat 1 DBL Mat        22
# 1 TPL Twin 1 DBL Mat       21
# 1 SGL 1 DBL Twin           19
# 1 TPL Mat 1 TPL Mat        18
# 1 DBL Mat 1 SGL            17
# Name: Rooms, dtype: int64

# %%
print('Top 11 room names represent ', df.Rooms.value_counts(normalize=True).head(11).sum() , ' of data')
print('-----------------------')
print(df.Rooms.value_counts(normalize=True).head(11))
# Out:
# Top 11 room names represent  0.9650260999254288  of data
# -----------------------
# 1 DBL Mat                0.432438
# 1 SGL                    0.260552
# 1 DBL Twin               0.122819
# 1 TPL Mat                0.058166
# 1 TPL Twin               0.033855
# 1 SUP                    0.024981
# 1 DBL Mat 1 DBL Mat      0.014765
# 1 SGL 1 SGL              0.007308
# 1 DBL Twin 1 DBL Twin    0.005145
# 1 DBL Mat 1 DBL Twin     0.002685
# 1 DBL Twin 1 DBL Mat     0.002312
# Name: Rooms, dtype: float64

# %%
df.Rooms.shape
# Out:
# (13410,)

# %%
#Removing Bookings that are not in top 11 types of room (1 DBL Mat,1 SGL, 1 DBL Twin, 1 TPL Mat,   1 TPL Twin, 1 SUP ,
#                                                       1 DBL Mat 1 DBL Mat  , 1 SGL 1 SGL
#                                                        1 DBL Twin 1 DBL Twin )
df = df.loc[(df['Rooms'] == '1 DBL Mat') | (df['Rooms'] == '1 SGL') | (df['Rooms'] == '1 DBL Twin')
       | (df['Rooms'] == '1 TPL Mat') | (df['Rooms'] == '1 TPL Twin') | (df['Rooms'] == '1 SUP')
       | (df['Rooms'] == '1 DBL Mat 1 DBL Mat') | (df['Rooms'] == '1 SGL 1 SGL') | (df['Rooms'] == '1 TPL Mat 1 TPL Mat')
        | (df['Rooms'] == '1 DBL Twin 1 DBL Twin')  | (df['Rooms'] == '1 DBL Twin 1 DBL Mat')
        | (df['Rooms'] == '1 DBL Mat 1 DBL Twin') | (df['Rooms'] == '1 SUP 1 SUP')
       | (df['Rooms'] == '1 TPL Twin 1 TPL Mat')  | (df['Rooms'] == '1 TPL Mat 1 TPL Twin')
        | (df['Rooms'] == '1 TPL Twin 1 TPL Twin')
           ]
df.shape
# Out:
# (12981, 18)

# %%
df.head()
# Out:
#        Number          Channel   Check in  Check out       Rooms  Persons  \
# 0  1133853485  Booking.com XML 2017-04-08 2017-04-09  1 TPL Twin        3
# 1  1189403050  Booking.com XML 2017-04-08 2017-04-09   1 DBL Mat        2
# 2  1868347451  Booking.com XML 2017-04-08 2017-04-09   1 DBL Mat        2
# 3  1426867077  Booking.com XML 2017-04-07 2017-04-09   1 DBL Mat        2
# 4   793922993      Expedia XML 2017-04-07 2017-04-09  1 DBL Twin        2
#
#    Adults  Children   Total  Commission  Prepaid    Country  \
# 0       3         0   79.34       14.28     0.00  Argentina
# 1       2         0   83.97       15.11     0.00  Argentina
# 2       2         0   97.19       17.49     0.00  Argentina
# 3       2         0  113.82       20.49     0.00    Uruguay
# 4       2         0  110.16        0.00   110.16        NaN
#
#      Reservation Date Date of creation or modification  Cancellation Date   \
# 0 2017-03-15 12:25:00              2017-03-17 01:07:00 2017-03-17 01:07:00
# 1 2017-03-30 22:50:00              2017-03-30 22:50:00                 NaT
# 2 2017-04-07 20:36:00              2017-04-07 20:36:00                 NaT
# 3 2017-01-27 14:34:00              2017-02-27 09:06:00 2017-02-27 09:06:00
# 4 2017-02-14 22:27:00              2017-02-14 22:28:00                 NaT
#
#        Payment    Status        Net
# 0  Credit card  Cancelled   65.0588
# 1  Credit card        New   68.8554
# 2  Credit card        New   79.6958
# 3  Credit card  Cancelled   93.3324
# 4  Credit card        New  110.1600

# %%
df.shape
# Out:
# (12981, 18)

# %%
#Separating (1 DBL Mat 1 DBL Mat)  ,( 1 SGL 1 SGL), ( 1 DBL Twin 1 DBL Twin) in two rows.
# 1: Non-combined rows have a 'Room' lenght of 10 characters max, using that as reference

# %%
df['len_rooms'] = df.Rooms.apply(lambda x: len(x))

# %%
df['len_rooms']
# Out:
# 0      10
# 1       9
# 2       9
# 3       9
# 4      10
#        ..
# 622    10
# 623     9
# 624     9
# 625     5
# 627     9
# Name: len_rooms, Length: 12981, dtype: int64

# %%
df.shape
# Out:
# (12981, 19)

# %%
items = df[df['len_rooms'] > 10]
items
# Out:
#           Number            Channel   Check in  Check out  \
# 93    1633849355    Booking.com XML 2017-03-30 2017-03-31
# 127   1373609356    Booking.com XML 2017-03-27 2017-03-30
# 135   1121819322    Booking.com XML 2017-03-26 2017-03-27
# 146   3361947602  Despegar PAM2 XML 2017-03-25 2017-03-30
# 147   1469749405    Booking.com XML 2017-03-24 2017-03-28
# ..           ...                ...        ...        ...
# 540  16748003902  Despegar PAM2 XML 2022-01-10 2022-01-11
# 576   3456523864    Booking.com XML 2022-01-07 2022-01-10
# 578   3573987818    Booking.com XML 2022-01-07 2022-01-08
# 617   2364168084    Booking.com XML 2022-01-02 2022-01-05
# 621   249-839754      Hotelbeds XML 2022-01-01 2022-01-02
#
#                      Rooms  Persons  Adults  Children   Total  Commission  \
# 93     1 DBL Mat 1 DBL Mat        4       4         0  115.46       20.78
# 127            1 SGL 1 SGL        2       2         0  366.94       66.05
# 135  1 TPL Twin 1 TPL Twin        6       6         0  133.88       24.10
# 146    1 DBL Mat 1 DBL Mat        4       4         0  457.16        0.00
# 147    1 DBL Mat 1 DBL Mat        4       4         0  481.00       86.58
# ..                     ...      ...     ...       ...     ...         ...
# 540   1 TPL Mat 1 TPL Twin        6       6         0  115.23        0.00
# 576   1 TPL Mat 1 TPL Twin        5       5         0  430.86       76.20
# 578    1 DBL Mat 1 DBL Mat        4       4         0   95.36       16.80
# 617    1 DBL Mat 1 DBL Mat        4       4         0  321.52       57.88
# 621    1 DBL Mat 1 DBL Mat        4       4         0  101.14       25.99
#
#      Prepaid    Country    Reservation Date Date of creation or modification  \
# 93      0.00  Argentina 2017-03-28 09:19:00              2017-03-28 09:19:00
# 127     0.00     Brazil 2017-03-17 09:51:00              2017-03-17 09:51:00
# 135     0.00  Argentina 2017-02-09 11:19:00              2017-02-09 11:19:00
# 146   457.16        NaN 2017-03-11 09:56:00              2017-03-11 09:59:00
# 147     0.00    Germany 2017-01-29 14:03:00              2017-01-29 14:04:00
# ..       ...        ...                 ...                              ...
# 540     0.00  Argentina 2021-12-27 20:00:00              2021-12-27 20:00:00
# 576     0.00        USA 2021-12-08 18:51:00              2021-12-31 18:39:00
# 578     0.00     Brazil 2021-12-13 21:51:00              2021-12-13 21:52:00
# 617     0.00  Argentina 2021-12-26 14:07:00              2021-12-26 14:29:00
# 621   101.14        NaN 2021-11-21 20:00:00              2021-11-22 12:02:00
#
#      Cancellation Date       Payment    Status        Net  len_rooms
# 93                  NaT  Credit card        New   94.6772         19
# 127                 NaT  Credit card        New  300.8908         11
# 135                 NaT  Credit card        New  109.7816         21
# 146                 NaT          NaN        New  457.1600         19
# 147                 NaT  Credit card        New  394.4200         19
# ..                  ...          ...        ...       ...        ...
# 540                 NaT  Credit card        New  115.2300         20
# 576                 NaT  Credit card   Modified  353.3052         20
# 578                 NaT  Credit card        New   78.1952         19
# 617 2021-12-26 14:28:00  Credit card  Cancelled  263.6464         19
# 621                 NaT  Credit card        New   75.8550         19
#
# [472 rows x 19 columns]

# %%
items = pd.concat([df[df['len_rooms'] >10]]*2, ignore_index=True)
items
# Out:
#           Number            Channel   Check in  Check out  \
# 0     1633849355    Booking.com XML 2017-03-30 2017-03-31
# 1     1373609356    Booking.com XML 2017-03-27 2017-03-30
# 2     1121819322    Booking.com XML 2017-03-26 2017-03-27
# 3     3361947602  Despegar PAM2 XML 2017-03-25 2017-03-30
# 4     1469749405    Booking.com XML 2017-03-24 2017-03-28
# ..           ...                ...        ...        ...
# 939  16748003902  Despegar PAM2 XML 2022-01-10 2022-01-11
# 940   3456523864    Booking.com XML 2022-01-07 2022-01-10
# 941   3573987818    Booking.com XML 2022-01-07 2022-01-08
# 942   2364168084    Booking.com XML 2022-01-02 2022-01-05
# 943   249-839754      Hotelbeds XML 2022-01-01 2022-01-02
#
#                      Rooms  Persons  Adults  Children   Total  Commission  \
# 0      1 DBL Mat 1 DBL Mat        4       4         0  115.46       20.78
# 1              1 SGL 1 SGL        2       2         0  366.94       66.05
# 2    1 TPL Twin 1 TPL Twin        6       6         0  133.88       24.10
# 3      1 DBL Mat 1 DBL Mat        4       4         0  457.16        0.00
# 4      1 DBL Mat 1 DBL Mat        4       4         0  481.00       86.58
# ..                     ...      ...     ...       ...     ...         ...
# 939   1 TPL Mat 1 TPL Twin        6       6         0  115.23        0.00
# 940   1 TPL Mat 1 TPL Twin        5       5         0  430.86       76.20
# 941    1 DBL Mat 1 DBL Mat        4       4         0   95.36       16.80
# 942    1 DBL Mat 1 DBL Mat        4       4         0  321.52       57.88
# 943    1 DBL Mat 1 DBL Mat        4       4         0  101.14       25.99
#
#      Prepaid    Country    Reservation Date Date of creation or modification  \
# 0       0.00  Argentina 2017-03-28 09:19:00              2017-03-28 09:19:00
# 1       0.00     Brazil 2017-03-17 09:51:00              2017-03-17 09:51:00
# 2       0.00  Argentina 2017-02-09 11:19:00              2017-02-09 11:19:00
# 3     457.16        NaN 2017-03-11 09:56:00              2017-03-11 09:59:00
# 4       0.00    Germany 2017-01-29 14:03:00              2017-01-29 14:04:00
# ..       ...        ...                 ...                              ...
# 939     0.00  Argentina 2021-12-27 20:00:00              2021-12-27 20:00:00
# 940     0.00        USA 2021-12-08 18:51:00              2021-12-31 18:39:00
# 941     0.00     Brazil 2021-12-13 21:51:00              2021-12-13 21:52:00
# 942     0.00  Argentina 2021-12-26 14:07:00              2021-12-26 14:29:00
# 943   101.14        NaN 2021-11-21 20:00:00              2021-11-22 12:02:00
#
#      Cancellation Date       Payment    Status        Net  len_rooms
# 0                   NaT  Credit card        New   94.6772         19
# 1                   NaT  Credit card        New  300.8908         11
# 2                   NaT  Credit card        New  109.7816         21
# 3                   NaT          NaN        New  457.1600         19
# 4                   NaT  Credit card        New  394.4200         19
# ..                  ...          ...        ...       ...        ...
# 939                 NaT  Credit card        New  115.2300         20
# 940                 NaT  Credit card   Modified  353.3052         20
# 941                 NaT  Credit card        New   78.1952         19
# 942 2021-12-26 14:28:00  Credit card  Cancelled  263.6464         19
# 943                 NaT  Credit card        New   75.8550         19
#
# [944 rows x 19 columns]

# %%
items['Net'] = items['Net'] /2
items['Total'] = items['Total'] /2
items['Commission'] = items['Commission'] /2
items['Persons'] = items['Persons'] /2
items['Adults'] = items['Adults'] /2

# %%
items
# Out:
#           Number            Channel   Check in  Check out  \
# 0     1633849355    Booking.com XML 2017-03-30 2017-03-31
# 1     1373609356    Booking.com XML 2017-03-27 2017-03-30
# 2     1121819322    Booking.com XML 2017-03-26 2017-03-27
# 3     3361947602  Despegar PAM2 XML 2017-03-25 2017-03-30
# 4     1469749405    Booking.com XML 2017-03-24 2017-03-28
# ..           ...                ...        ...        ...
# 939  16748003902  Despegar PAM2 XML 2022-01-10 2022-01-11
# 940   3456523864    Booking.com XML 2022-01-07 2022-01-10
# 941   3573987818    Booking.com XML 2022-01-07 2022-01-08
# 942   2364168084    Booking.com XML 2022-01-02 2022-01-05
# 943   249-839754      Hotelbeds XML 2022-01-01 2022-01-02
#
#                      Rooms  Persons  Adults  Children    Total  Commission  \
# 0      1 DBL Mat 1 DBL Mat      2.0     2.0         0   57.730      10.390
# 1              1 SGL 1 SGL      1.0     1.0         0  183.470      33.025
# 2    1 TPL Twin 1 TPL Twin      3.0     3.0         0   66.940      12.050
# 3      1 DBL Mat 1 DBL Mat      2.0     2.0         0  228.580       0.000
# 4      1 DBL Mat 1 DBL Mat      2.0     2.0         0  240.500      43.290
# ..                     ...      ...     ...       ...      ...         ...
# 939   1 TPL Mat 1 TPL Twin      3.0     3.0         0   57.615       0.000
# 940   1 TPL Mat 1 TPL Twin      2.5     2.5         0  215.430      38.100
# 941    1 DBL Mat 1 DBL Mat      2.0     2.0         0   47.680       8.400
# 942    1 DBL Mat 1 DBL Mat      2.0     2.0         0  160.760      28.940
# 943    1 DBL Mat 1 DBL Mat      2.0     2.0         0   50.570      12.995
#
#      Prepaid    Country    Reservation Date Date of creation or modification  \
# 0       0.00  Argentina 2017-03-28 09:19:00              2017-03-28 09:19:00
# 1       0.00     Brazil 2017-03-17 09:51:00              2017-03-17 09:51:00
# 2       0.00  Argentina 2017-02-09 11:19:00              2017-02-09 11:19:00
# 3     457.16        NaN 2017-03-11 09:56:00              2017-03-11 09:59:00
# 4       0.00    Germany 2017-01-29 14:03:00              2017-01-29 14:04:00
# ..       ...        ...                 ...                              ...
# 939     0.00  Argentina 2021-12-27 20:00:00              2021-12-27 20:00:00
# 940     0.00        USA 2021-12-08 18:51:00              2021-12-31 18:39:00
# 941     0.00     Brazil 2021-12-13 21:51:00              2021-12-13 21:52:00
# 942     0.00  Argentina 2021-12-26 14:07:00              2021-12-26 14:29:00
# 943   101.14        NaN 2021-11-21 20:00:00              2021-11-22 12:02:00
#
#      Cancellation Date       Payment    Status        Net  len_rooms
# 0                   NaT  Credit card        New   47.3386         19
# 1                   NaT  Credit card        New  150.4454         11
# 2                   NaT  Credit card        New   54.8908         21
# 3                   NaT          NaN        New  228.5800         19
# 4                   NaT  Credit card        New  197.2100         19
# ..                  ...          ...        ...       ...        ...
# 939                 NaT  Credit card        New   57.6150         20
# 940                 NaT  Credit card   Modified  176.6526         20
# 941                 NaT  Credit card        New   39.0976         19
# 942 2021-12-26 14:28:00  Credit card  Cancelled  131.8232         19
# 943                 NaT  Credit card        New   37.9275         19
#
# [944 rows x 19 columns]

# %%
items.Rooms.value_counts()
# Out:
# 1 DBL Mat 1 DBL Mat      396
# 1 SGL 1 SGL              196
# 1 DBL Twin 1 DBL Twin    138
# 1 DBL Mat 1 DBL Twin      72
# 1 DBL Twin 1 DBL Mat      62
# 1 TPL Mat 1 TPL Mat       36
# 1 TPL Mat 1 TPL Twin      16
# 1 TPL Twin 1 TPL Twin     14
# 1 TPL Twin 1 TPL Mat       8
# 1 SUP 1 SUP                6
# Name: Rooms, dtype: int64

# %%
items = items.replace({'Rooms' : { '1 DBL Mat 1 DBL Mat' : '1 DBL Mat', '1 SGL 1 SGL' : '1 SGL', '1 DBL Twin 1 DBL Twin' : '1 DBL Twin', 
                                 '1 DBL Mat 1 DBL Twin' : '1 DBL Mat', '1 DBL Twin 1 DBL Mat' : '1 DBL Twin',
                                  '1 TPL Mat 1 TPL Mat' : '1 TPL Mat', '1 TPL Twin 1 TPL Twin' : '1 TPL Twin',
                                  '1 TPL Mat 1 TPL Twin ' : '1 TPL Mat', '1 TPL Twin 1 TPL Mat' : '1 TPL Twin',
                                  '1 SUP 1 SUP' : '1 SUP' , '1 TPL 1 TPL' : '1 TPL Mat', '1 TPL 1 TPL ' : '1 TPL Mat',
                                 '1 TPL Mat 1 TPL Twin' : '1 TPL Twin'}})
items.Rooms.value_counts()
# Out:
# 1 DBL Mat     468
# 1 DBL Twin    200
# 1 SGL         196
# 1 TPL Twin     38
# 1 TPL Mat      36
# 1 SUP           6
# Name: Rooms, dtype: int64

# %%
df.shape
# Out:
# (12981, 19)

# %%
df[df['len_rooms'] >10].shape
# Out:
# (472, 19)

# %%
df[df['len_rooms'] <=10].shape
# Out:
# (12509, 19)

# %%
df = df[df['len_rooms'] <=10]

# %%
df.shape
# Out:
# (12509, 19)

# %%
print(items.shape)

print(df.shape[0] + items.shape[0])
# Out:
# (944, 19)
# 13453

# %%
df = pd.concat([df, items],axis=0)
df.shape
# Out:
# (13453, 19)

# %%
df
# Out:
#           Number            Channel   Check in  Check out       Rooms  \
# 0     1133853485    Booking.com XML 2017-04-08 2017-04-09  1 TPL Twin
# 1     1189403050    Booking.com XML 2017-04-08 2017-04-09   1 DBL Mat
# 2     1868347451    Booking.com XML 2017-04-08 2017-04-09   1 DBL Mat
# 3     1426867077    Booking.com XML 2017-04-07 2017-04-09   1 DBL Mat
# 4      793922993        Expedia XML 2017-04-07 2017-04-09  1 DBL Twin
# ..           ...                ...        ...        ...         ...
# 939  16748003902  Despegar PAM2 XML 2022-01-10 2022-01-11  1 TPL Twin
# 940   3456523864    Booking.com XML 2022-01-07 2022-01-10  1 TPL Twin
# 941   3573987818    Booking.com XML 2022-01-07 2022-01-08   1 DBL Mat
# 942   2364168084    Booking.com XML 2022-01-02 2022-01-05   1 DBL Mat
# 943   249-839754      Hotelbeds XML 2022-01-01 2022-01-02   1 DBL Mat
#
#      Persons  Adults  Children    Total  Commission  Prepaid    Country  \
# 0        3.0     3.0         0   79.340      14.280     0.00  Argentina
# 1        2.0     2.0         0   83.970      15.110     0.00  Argentina
# 2        2.0     2.0         0   97.190      17.490     0.00  Argentina
# 3        2.0     2.0         0  113.820      20.490     0.00    Uruguay
# 4        2.0     2.0         0  110.160       0.000   110.16        NaN
# ..       ...     ...       ...      ...         ...      ...        ...
# 939      3.0     3.0         0   57.615       0.000     0.00  Argentina
# 940      2.5     2.5         0  215.430      38.100     0.00        USA
# 941      2.0     2.0         0   47.680       8.400     0.00     Brazil
# 942      2.0     2.0         0  160.760      28.940     0.00  Argentina
# 943      2.0     2.0         0   50.570      12.995   101.14        NaN
#
#        Reservation Date Date of creation or modification  Cancellation Date   \
# 0   2017-03-15 12:25:00              2017-03-17 01:07:00 2017-03-17 01:07:00
# 1   2017-03-30 22:50:00              2017-03-30 22:50:00                 NaT
# 2   2017-04-07 20:36:00              2017-04-07 20:36:00                 NaT
# 3   2017-01-27 14:34:00              2017-02-27 09:06:00 2017-02-27 09:06:00
# 4   2017-02-14 22:27:00              2017-02-14 22:28:00                 NaT
# ..                  ...                              ...                 ...
# 939 2021-12-27 20:00:00              2021-12-27 20:00:00                 NaT
# 940 2021-12-08 18:51:00              2021-12-31 18:39:00                 NaT
# 941 2021-12-13 21:51:00              2021-12-13 21:52:00                 NaT
# 942 2021-12-26 14:07:00              2021-12-26 14:29:00 2021-12-26 14:28:00
# 943 2021-11-21 20:00:00              2021-11-22 12:02:00                 NaT
#
#          Payment    Status        Net  len_rooms
# 0    Credit card  Cancelled   65.0588         10
# 1    Credit card        New   68.8554          9
# 2    Credit card        New   79.6958          9
# 3    Credit card  Cancelled   93.3324          9
# 4    Credit card        New  110.1600         10
# ..           ...        ...       ...        ...
# 939  Credit card        New   57.6150         20
# 940  Credit card   Modified  176.6526         20
# 941  Credit card        New   39.0976         19
# 942  Credit card  Cancelled  131.8232         19
# 943  Credit card        New   37.9275         19
#
# [13453 rows x 19 columns]

# %%
df['Numero'] = range(1, len(df) + 1)

# %%
df.reset_index(inplace=True, drop=True)

# %%
df
# Out:
#             Number            Channel   Check in  Check out       Rooms  \
# 0       1133853485    Booking.com XML 2017-04-08 2017-04-09  1 TPL Twin
# 1       1189403050    Booking.com XML 2017-04-08 2017-04-09   1 DBL Mat
# 2       1868347451    Booking.com XML 2017-04-08 2017-04-09   1 DBL Mat
# 3       1426867077    Booking.com XML 2017-04-07 2017-04-09   1 DBL Mat
# 4        793922993        Expedia XML 2017-04-07 2017-04-09  1 DBL Twin
# ...            ...                ...        ...        ...         ...
# 13448  16748003902  Despegar PAM2 XML 2022-01-10 2022-01-11  1 TPL Twin
# 13449   3456523864    Booking.com XML 2022-01-07 2022-01-10  1 TPL Twin
# 13450   3573987818    Booking.com XML 2022-01-07 2022-01-08   1 DBL Mat
# 13451   2364168084    Booking.com XML 2022-01-02 2022-01-05   1 DBL Mat
# 13452   249-839754      Hotelbeds XML 2022-01-01 2022-01-02   1 DBL Mat
#
#        Persons  Adults  Children    Total  Commission  Prepaid    Country  \
# 0          3.0     3.0         0   79.340      14.280     0.00  Argentina
# 1          2.0     2.0         0   83.970      15.110     0.00  Argentina
# 2          2.0     2.0         0   97.190      17.490     0.00  Argentina
# 3          2.0     2.0         0  113.820      20.490     0.00    Uruguay
# 4          2.0     2.0         0  110.160       0.000   110.16        NaN
# ...        ...     ...       ...      ...         ...      ...        ...
# 13448      3.0     3.0         0   57.615       0.000     0.00  Argentina
# 13449      2.5     2.5         0  215.430      38.100     0.00        USA
# 13450      2.0     2.0         0   47.680       8.400     0.00     Brazil
# 13451      2.0     2.0         0  160.760      28.940     0.00  Argentina
# 13452      2.0     2.0         0   50.570      12.995   101.14        NaN
#
#          Reservation Date Date of creation or modification  \
# 0     2017-03-15 12:25:00              2017-03-17 01:07:00
# 1     2017-03-30 22:50:00              2017-03-30 22:50:00
# 2     2017-04-07 20:36:00              2017-04-07 20:36:00
# 3     2017-01-27 14:34:00              2017-02-27 09:06:00
# 4     2017-02-14 22:27:00              2017-02-14 22:28:00
# ...                   ...                              ...
# 13448 2021-12-27 20:00:00              2021-12-27 20:00:00
# 13449 2021-12-08 18:51:00              2021-12-31 18:39:00
# 13450 2021-12-13 21:51:00              2021-12-13 21:52:00
# 13451 2021-12-26 14:07:00              2021-12-26 14:29:00
# 13452 2021-11-21 20:00:00              2021-11-22 12:02:00
#
#        Cancellation Date       Payment    Status        Net  len_rooms  Numero
# 0     2017-03-17 01:07:00  Credit card  Cancelled   65.0588         10       1
# 1                     NaT  Credit card        New   68.8554          9       2
# 2                     NaT  Credit card        New   79.6958          9       3
# 3     2017-02-27 09:06:00  Credit card  Cancelled   93.3324          9       4
# 4                     NaT  Credit card        New  110.1600         10       5
# ...                   ...          ...        ...       ...        ...     ...
# 13448                 NaT  Credit card        New   57.6150         20   13449
# 13449                 NaT  Credit card   Modified  176.6526         20   13450
# 13450                 NaT  Credit card        New   39.0976         19   13451
# 13451 2021-12-26 14:28:00  Credit card  Cancelled  131.8232         19   13452
# 13452                 NaT  Credit card        New   37.9275         19   13453
#
# [13453 rows x 20 columns]

# %%
### UNFINISHED - Plotting room types

# %% [markdown]
# ####Creating another column RoomTypes (as Mat and Single are same price)

# %%
df.Rooms.value_counts()
# Out:
# 1 DBL Mat     6267
# 1 SGL         3690
# 1 DBL Twin    1847
# 1 TPL Mat      816
# 1 TPL Twin     492
# 1 SUP          341
# Name: Rooms, dtype: int64

# %%
df['RoomType'] = df.Rooms
df['RoomType'] = df.RoomType.str.replace('Mat', '')
df['RoomType'] = df.RoomType.str.replace('Twin', '')

# %%
import plotly.graph_objs as go
import plotly.express as px


fig = px.histogram(df, x='Rooms', color='Rooms', color_discrete_sequence=px.colors.qualitative.Set2, 
                  ).update_xaxes(categoryorder='total descending')

fig.show()
# Out:
# <div>                            <div id="7a56f5c8-5924-4827-ac9d-0b12dee0e53c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a56f5c8-5924-4827-ac9d-0b12dee0e53c")) {                    Plotly.newPlot(                        "7a56f5c8-5924-4827-ac9d-0b12dee0e53c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Rooms=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1 TPL Twin","marker":{"color":"rgb(102,194,165)","pattern":{"shape":""}},"name":"1 TPL Twin","offsetgroup":"1 TPL Twin","orientation":"v","showlegend":true,"x":["1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twin","1 TPL Twi ...

# %%
df['Country'].fillna('None', inplace=True)

# %%
country = df.groupby(['Country']).agg({'Channel': 'count', 'RoomType': 'sum'})
country
#country.sort_values(by='Channel', ascending=False).head(20)

# %%
#fig2 = px.line(country, x='RoomTypes', color='Country', color_discrete_sequence=px.colors.qualitative.Dark2)
#fig2.show()

# %%
df[df.Rooms == '1 SUP']

# %%
df.head()

# %%
type(df['Check out'][0])

# %%
#Cant de noches

df['Nights'] = df['Check out']-df['Check in']
df['Nights'] = df['Nights'].dt.days

# %%
df['Net_per_night'] = df['Net']/df['Nights']
df['Net_per_night']

# %%
#BOOKING ANTICIPATION
df['Antic_days'] = df['Check in']- df['Reservation Date']
df['Antic_days'] = df['Antic_days'].dt.days
df['Antic_days']

# %%
s = df.groupby('Reservation Date').size()
s.plot()

# %%
#sns.countplot(x='Reservation Date', data=df)
#plt.show()

# %%
df.columns

# %% [markdown]
# # EDA

# %%
df.columns

# %% [markdown]
# ## Occupancy and RevPar

# %%
# Cheking occupancy per day
df2 = df.copy()
df2 = df2[(df2['Status ']=='New') | (df2['Status ']=='Modified')].reset_index()

# %%
df2.drop(df2[df2['Net_per_night']>300].index, inplace=True)

# %%
df2['DATE'] = [pd.date_range(s, e, freq='d',closed='left') for s, e in
              zip(pd.to_datetime(df2['Check in']), pd.to_datetime(df2['Check out']))]

# %%
occupancy = df2.explode('DATE').groupby('DATE').size()

# %%
occupancy = occupancy.reset_index()
occupancy

# %%
occupancy.columns = ['DATE', 'Nights']

# %%
occupancy['DATE'] = pd.to_datetime(occupancy['DATE'])
occupancy['day_of_week'] = occupancy['DATE'].dt.day_name()
occupancy['year'] = pd.DatetimeIndex(occupancy['DATE']).year
occupancy['month'] = pd.DatetimeIndex(occupancy['DATE']).month
occupancy['day'] = pd.DatetimeIndex(occupancy['DATE']).day
occupancy['year_month'] = occupancy['DATE'].dt.to_period('M')

occupancy

# %%
from sklearn import preprocessing

# %%
# Ocuppancy rate: rooms booked / rooms listed
occupancy['occ_rate'] = occupancy.Nights / 45
occupancy['occ_rate'] = occupancy['occ_rate'].round(decimals=2)
occupancy.head()

# %% [markdown]
# ### Viz occupancy

# %%
#!pip install plotly-calplot

# %%
#!pip install ipywidgets
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
occupancy['DATE'] = pd.to_datetime(occupancy['DATE'])

# %%
type(occupancy.DATE[5])

# %%
# SUM REVENUE PER NIGHT

ttl_net_per_nt = df2.explode('DATE').groupby('DATE')['Net_per_night'].sum()
ttl_net_per_nt = ttl_net_per_nt.reset_index()
ttl_net_per_nt

# %%
occupancy['ttl_net_per_nt'] = ttl_net_per_nt['Net_per_night']

# %%
occupancy

# %%
occupancy['RevPAR'] = occupancy['ttl_net_per_nt']/45
occupancy

# %%
occupancy['ADR'] = occupancy['ttl_net_per_nt']/occupancy['Nights']
occupancy

# %%
occupancy = occupancy[occupancy['DATE']<= '2022-03-31']

# %%
# SUM children PER NIGHT

children = df2.explode('DATE').groupby('DATE')['Children'].sum()
children = children.reset_index()
occupancy['Children'] = children['Children']
occupancy

# %%
 #create new df
occ_heat = occupancy.copy()
#Set orderdate as index
occ_heat.set_index('DATE', inplace = True)

# %%
occ_heat.head()

# %%
#!pip install colour

# %%
from colour import Color
grey = Color("grey")
colors = list(grey.range_to(Color("green"),10))
    
# colors is now a list of length 10
# Containing: 
# [<Color red>, <Color #f13600>, <Color #e36500>, <Color #d58e00>, <Color #c7b000>, <Color #a4b800>, <Color #72aa00>, <Color #459c00>, <Color #208e00>, <Color green>]

# %%
#!pip install calplot

# %%
import calplot
pl1 = calplot.calplot(data = occ_heat['occ_rate'],how = 'sum', cmap = 'YlOrBr',
                      figsize = (16, 8), suptitle = "Occupancy rate", fillcolor='lightgrey',
                     daylabels= ['Mo', 'Tu', 'We', 'Th', 'Fr', 'Sa', 'Su'])

# %%
pl2 = calplot.calplot(data = occ_heat['ttl_net_per_nt'],how = 'sum', cmap = 'GnBu',
                      figsize = (16, 8), suptitle = "Revenue per Day", fillcolor='lightgrey', 
                     daylabels= ['Mo', 'Tu', 'We', 'Th', 'Fr', 'Sa', 'Su'])

# %%
pl3 = calplot.calplot(data = occ_heat['RevPAR'],how = 'sum', cmap = 'GnBu',
                      figsize = (16, 8), suptitle = "RevPAR", fillcolor='lightgrey', 
                     daylabels= ['Mo', 'Tu', 'We', 'Th', 'Fr', 'Sa', 'Su'], 
                     )

# %%
pl1 = calplot.calplot(data = occ_heat['ADR'],how = 'sum', cmap = 'GnBu',
                      figsize = (16, 8), suptitle = "ADR", fillcolor='lightgrey', daylabels= ['Mo', 'Tu', 'We', 'Th', 'Fr', 'Sa', 'Su'])

# %%
pl7 = calplot.calplot(data = occ_heat['Children'],how = 'sum', cmap = 'GnBu',
                      figsize = (16, 8), suptitle = " Total Children in Hotel", fillcolor='lightgrey')

# %%
occ_heat

# %%
nuevogrupo = occ_heat.groupby('day_of_week')['Nights'].sum().reset_index()
nuevogrupo

# %%
ax = sns.barplot(x="day_of_week", y='Nights', data=nuevogrupo , order=['Monday', 'Tuesday', 'Wednesday', 
                                                          'Thursday', 'Friday', 'Saturday', 'Sunday'],
                   palette='Accent' )
sns.set(rc = {'figure.figsize':(10,8)})

# %%
type(occupancy.DATE[5])

# %%
occupancy.sort_values(by='DATE')

# %%
occupancy.groupby(['year','day_of_week'])['Nights'].sum()

# %%
# Here we use a column with categorical data
fig = px.scatter(occupancy, x='DATE')
fig.show()

# %%
df

# %%
country = df.groupby('Country')['Channel'].count().reset_index()
country

# %%
country = country.sort_values(by='Channel', ascending=False)

# %%
# Here we use a column with categorical data
fig445 = px.bar(country.head(10), x="Country", y='Channel', title="Bookings per Nationality", text_auto=True,
               labels={
                     "Country": "Country", 'Channel' : 'Count'})

fig445.show()

# %%
df2.columns

# %%
#df2.groupby['RoomType'].count

# %%
occ_heat.mean()

# %%
fig = px.scatter(df, x="RoomType", color="Country")
fig.update_traces(marker_size=10)
fig.show()

# %%
fig99 = go.Figure()
fig99.add_trace(go.Scatter(x=df2.RoomType))

# %%
df2.head()

# %%
df

# %%
df['year_arrival'] = pd.DatetimeIndex(df['Check in']).year

# %%
df.head()

# %%
df['month_arrival'] = pd.DatetimeIndex(df['Check in']).month
df['day_arrival'] = pd.DatetimeIndex(df['Check in']).day

# %%
df['month_year_arrival'] = pd.to_datetime(df['Check in']).dt.to_period('M')

# %%
df['Check in'] = pd.to_datetime(df['Check in'])
df['day_of_week_arrival'] = df['Check in'].dt.day_name()

# %%
df.head()

# %%
df.shape

# %%
sns.distplot(df['Net'])

# %%
sns.distplot(df['year_arrival'])

# %%
a = sns.barplot(df['month_arrival'], bins=12 , axlabel='Month')
a.figure.set_size_inches(15,10)

# %%
nightspermonth = occ_heat.groupby('month')['Nights'].sum().reset_index()

# %%
ax3 = sns.barplot(x="month", y="Nights", data=nightspermonth)
ax3.set_xticklabels(['Jan','Feb','Mar','Apr','May','Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
ax3.set_title('Annual Seasonality')

# %%
occ_heat

# %%
otrogrupito = occ_heat.groupby('month').agg({"Nights": "sum",
                               'day' : 'count'}).reset_index()

# %%
otrogrupito['inventario'] = otrogrupito['day']*45
otrogrupito['occ'] = (otrogrupito['Nights'] / otrogrupito['inventario'])*100

# %%
otrogrupito

# %%
r = sns.barplot(x="month", y="occ", data=otrogrupito)
r.set_xticklabels(['Jan','Feb','Mar','Apr','May','Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
r.set_title('Seasonality')

# %%
#df['month_short'] = 
df['month_arrival'].dt.strftime('%b')

# %%
ax = sns.distplot(df2, kde=False, bins=12)
ax.set_title('Distribution of Flavor Purchases\nNumber Purchased')
ax.set(ylabel='Count', xlabel='Number of Flavors Purchased')
n = 20
ax.set_xticks(range(n))
ax.set_xticklabels(range(n))

ax2 = plt.twinx()
ax2 = sns.lineplot(df2, kde=True, hist=False, ax=ax2)
ax2.set_ylabel('density')
plt.show()

# %%
sns.distplot(df['day_arrival'])

# %%
df.columns

# %%
#sns.histplot(data=df, x='year_arrival', y= 'Net', kind='scatter')

# %%
df

# %%
type(df)

# %%
df.columns

# %%
sns.pairplot(df[['Channel', 'Check in', 'Check out', 'Rooms', 'Persons', 'Country',
       'Reservation Date', 'Date of creation or modification',
       'Cancellation Date ', 'Payment', 'Status ', 'Net']])

# %%
df.describe().T

# %% [markdown]
# # Customer Segmentation - RMF

# %% [raw]
# df2.Email.unique()

# %% [raw]
# df.columns

# %% [raw]
# df2['Email'].fillna('None', inplace=True)

# %% [raw]
# df2['Email_2'] = df2['Email']

# %% [raw]
# df2.loc[df2['Email_2'].str.contains('@guest.booking.com'), 'Email_2'] = df2[df2['Email'].str.contains('@guest.booking.com')]['Email'].apply(lambda x: x[:6])

# %% [raw]
# df2['Email'] = df2['Email_2']

# %% [markdown]
# ## Recency --- *by check-in or by reservation date?*
# Let's try check in first.
# df2 is the non-cancelled bookings

# %% [raw]
# df2['Check in'].max()

# %% [raw]
# df2['Reservation Date'].max()

# %% [raw]
# df2['Check in']

# %% [raw]
# #2017-04-08 to 2022-03-03

# %% [raw]
# max_date = max(df2['Check in'])
# max_date

# %% [raw]
# max_date - df2['Check in']

# %% [raw]
# # Compute the difference between max date and transaction date
#
# df2['Diff'] = max_date - df2['Check in']
# df2.head()

# %% [raw]
# rfm_p = df2.groupby('Email')['Diff'].min()
# rfm_p

# %% [raw]
# # Compute last transaction date to get the recency of customers
#
# rfm_p = df2.groupby('Email')['Diff'].min()
# rfm_p = rfm_p.sort_values(ascending = True)
#
# type(rfm_p)
# rfm_p

# %% [raw]
# rfm_p = rfm_p.reset_index()
# rfm_p.head()

# %% [raw]
# # Extract number of days only
#
# rfm_p['Diff'] = rfm_p['Diff'].dt.days
# rfm_p.head()

# %% [raw]
# rfm_p.tail()

# %% [markdown]
# ## Monetary

# %% [raw]
# df2.head(2)

# %% [raw]
# rfm_m = df2.groupby('Email')['Net'].sum()
# rfm_m

# %% [raw]
# rfm_m = rfm_m.sort_values(ascending = True)
#
# rfm_m = rfm_m.reset_index()
# rfm_m.head()

# %% [markdown]
# ## Frequency

# %% [raw]
# # New Attribute : Frequency
#
# rfm_f = df2.groupby('Email')['Number'].count()
# rfm_f

# %% [raw]
# rfm_f = rfm_f.reset_index()
# rfm_f.columns = ['Email', 'Frequency']
# rfm_f.head()

# %% [raw]
# ## PROBLEMA: Booking genera un mail diferente cada vez que se hace una reserva. ej vicdel.123456@guest.booking.com
# #user could be primeras 6 letras del mail, o solo las letras

# %% [raw]
# print('Recency: \n', rfm_p.head(2))
# print()
# print('Monetary:\n', rfm_m.head(2))
# print()
# print('Freq:\n', rfm_f.head(2))

# %% [raw]
# # Merging the two dfs
#
# rfm = pd.merge(rfm_m, rfm_f, on='Email', how='inner')
# rfm.head()

# %% [raw]
# # Merge all dataframes to get the final RFM dataframe
#
# rfm = pd.merge(rfm, rfm_p, on='Email', how='inner')
# rfm.columns = ['Email', 'MonetaryValue', 'Frequency', 'Recency']
# rfm.head()

# %% [markdown]
# # Customer segmentation based on K-Means

# %% [markdown]
# ## Data preparation
# We must scale the data before building a KMeans model
#
# a) Select the interested variables
# b) Instantiate the scaling method: preprocessing.MinMaxScaler()
# c) Transform the original data into a scaled data: scaler.fit_transform(dataset)

# %% [raw]
# # Select the interested variables
#
# rfm_df = rfm[['MonetaryValue', 'Frequency', 'Recency']]

# %% [raw]
# rfm_df.describe().T

# %% [raw]
# # plot the distribution of RFM values
# plt.subplots(figsize=(10, 12))
#
# plt.subplot(3, 1, 1);
# sns.distplot(rfm.Recency, label = 'Recency')
#
# plt.subplot(3, 1, 2);
# sns.distplot(rfm.Frequency, label = 'Frequency')
#
# plt.subplot(3, 1, 3);
# sns.distplot(rfm.MonetaryValue, label = 'Monetary Value')
#
# plt.style.use('fivethirtyeight')
# plt.tight_layout()
# plt.show();

# %% [raw]
# rfm_log = rfm[['Recency', 'Frequency', 'MonetaryValue']].apply(np.log1p,
#                                                                axis = 1).round(3)
# rfm_log

# %% [raw]
# rfm_log.isnull().sum()

# %% [raw]
# # plot the distribution of RFM values
# #plt.subplots(figsize=(10, 12))
# plt.subplot(3, 1, 1)
# sns.distplot(rfm_log.Recency, label = 'Recency')
#
# plt.subplot(3, 1, 2)
# sns.distplot(rfm_log.Frequency, label = 'Frequency')
#
# plt.subplot(3, 1, 3)
# sns.distplot(rfm_log.MonetaryValue, label = 'Monetary Value')
#
#
# plt.show()

# %% [markdown]
# ### Let's scale the data

# %% [raw]
# # Normalize the variables with MinMaxScaler
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
#
# #Store it separately for clustering
# rfm_df_scaled = scaler.fit_transform(rfm_log)

# %% [raw]
# rfm_df_scaled

# %% [raw]
# rfm_df_scaled = pd.DataFrame(rfm_df_scaled)
# rfm_df_scaled
# rfm_df_scaled.columns = ['MonetaryValue', 'Frequency', 'Recency']

# %% [raw]
# rfm_df_scaled.head()

# %% [raw]
# rfm_df_scaled.describe().T

# %% [markdown]
# ## Model building: K-Means
#
# `KMeans` algorithm to decide the optimum cluster number, KMeans++ using Elbow Mmethod to figure out *K* for `KMeans`
#
# K-means clustering is one of the simplest and popular unsupervised machine learning algorithms.<br>
#
# The algorithm works as follows:
#
# - First we initialize k points, called means, randomly.
# - We categorize each item to its closest mean and we update the mean’s coordinates, which are the averages of the items categorized in that mean so far.
# - We repeat the process for a given number of iterations and at the end, we have our clusters.

# %% [raw]
# from sklearn.cluster import KMeans
# inertia = []
#
# #First : Get the Best KMeans
# ks = range(1,20)
#
# for i in ks:
#     kmeans = KMeans(n_clusters= i, random_state=7)
#     kmeans.fit(rfm_df_scaled)
#     inertia.append(kmeans.inertia_)
#
#     #inertia_ is the formula used to segregate the data points
#     # into clusters

# %% [raw]
# # Plot ks vs inertias
# f, ax = plt.subplots(figsize=(15, 8))
# plt.plot(ks, inertia, '-o')
#
# plt.xlabel('Number of clusters, k')
# plt.ylabel('Inertia')
# plt.xticks(ks)
# plt.style.use('ggplot')
# plt.title('What is the Best Number for KMeans ?')
# plt.show()

# %% [raw]
# from kneed import KneeLocator
# kl = KneeLocator(ks, inertia,curve="convex", direction="decreasing")
# kl

# %% [raw]
# print('The elbow point of your model is:', kl.elbow)

# %% [raw]
# # Final model with k=4
# kmeans = KMeans(n_clusters=4,
#                 max_iter=400, random_state=42)
#
# kmeans.fit(rfm_df_scaled)

# %% [raw]
# rfm_df_scaled

# %% [raw]
# # assign the label
# rfm_df_scaled['cluster_id'] = kmeans.labels_
# rfm_df_scaled.head()

# %% [raw]
# rfm_df_scaled['cluster_id'].value_counts()

# %% [raw]
# rfm_df_scaled.groupby('cluster_id').count()

# %% [raw]
# rfm_df['cluster_id'] = kmeans.labels_

# %% [raw]
# # Visualization
# def plot_clusters(df_sc, var1, var2,colors):
#     """
#     Function to plot each pair of variables after clustering it with Kmeans
#
#     input: df_sc -> scaled dataset
#            var1 -> variable 1 (x axis)
#            var2 -> variable 2 (y axis)
#            colors -> list of the colors for the clusters
#     """
#
#     total_clusters = df_sc.cluster_id.nunique()
#     fig = px.scatter(df_sc, x = var1,
#                  y = var2, color = df_sc.columns[len(df_sc.columns)-1],
#                      color_continuous_scale=colors)
#     fig.update_layout(coloraxis_showscale=False)
#     fig.show()

# %% [raw]
# colors_clusters = ['Coral', 'DarkCyan', 'DarkSeaGreen',
#                    'Gold']

# %% [raw]
# plot_clusters(rfm_df_scaled, 'Frequency', 'Recency', colors_clusters)

# %% [raw]
# rfm_df['cluster_id'] = kmeans.labels_

# %% [raw]
# plot_clusters(rfm_df, 'Frequency', 'Recency',colors_clusters)

# %% [raw]
# plot_clusters(rfm_df_scaled, 'Frequency', 'MonetaryValue',colors_clusters)

# %% [raw]
# plot_clusters(rfm_df_scaled, 'Recency', 'MonetaryValue',colors_clusters)

# %% [raw]
# #Barplots
# mean_clusters = rfm_df.groupby('cluster_id').mean().reset_index()
# mean_clusters

# %% [raw]
# colors_clusters

# %% [raw]
# # Step 1: Create the traces of the plots
# fig = px.bar(mean_clusters, x = 'cluster_id',
#                  y = 'MonetaryValue', color='cluster_id',
#                  color_continuous_scale=  colors_clusters)
#
# # Step 2: Update the layout of the plot
# fig.update_layout(barmode ='group')
#
# fig.show()

# %% [raw]
# fig = px.bar(mean_clusters, x = 'cluster_id',
#                  y = 'Recency', color='cluster_id',
#                  color_continuous_scale=  colors_clusters)
#
# # Step 2: Update the layout of the plot
# fig.update_layout(barmode='group')
#
# fig.show()

# %% [raw]
# fig = px.bar(mean_clusters, x = 'cluster_id',
#                  y = 'Frequency', color='cluster_id',
#                  color_continuous_scale=  colors_clusters)
#
# # Step 2: Update the layout of the plot
# fig.update_layout(barmode='group')
#
# fig.show()

# %% [raw]
# mean_clusters

# %% [raw]
# rfm_df_scaled

# %% [raw]
# df2.head()

# %% [raw]
# lista = df2['Email_2'].unique()
# df2['Email_2'].unique()

# %% [raw]
# lista_2 = np.arange(0,6886)

# %% [raw]
# dict_map = dict(zip(lista, lista_2))

# %% [raw]
# dict_map

# %% [markdown]
# # Back to data handling

# %%
df2.head()

# %%
df2[df2['Net_per_night']>180]

# %%
occupancy

# %%
occ_heat

# %%
occ_heat['event'] = 0

# %%
occ_heat.loc['2022-04-09', 'event']

# %% [markdown]
# # FORECASTING

# %%
occ_heat.ADR

# %%
occ_heat.ADR.plot(grid=True, figsize=(20, 10))

plt.show()

# %%
occ_heat.columns

# %%
#data = pd.DataFrame(values, dates, columns=["A", "B", "C", "D"])
datita = datita.rolling(7).mean()

sns.lineplot(data=datita, palette="tab10", linewidth=2.5)

# %%
datita = datita[['Nights','occ_rate', 'ttl_net_per_nt', 'RevPAR', 'ADR' ]]
datita

# %%
fig3 = px.line(ocupacionmensual, x='year_month', y='occ_rate', title='Daily Occupation Rate 2017-2022',)
fig3.show()

# %%
#!pip install pystan
#!pip install fbprophet

# %%
# check prophet version
import fbprophet
# print version number
print('Prophet %s' % fbprophet.__version__)

# %%
occ2 = occ_heat.ADR.reset_index()
occ2

# %%
occ_heat.shape

# %%
# fit prophet model on occ2

from fbprophet import Prophet

# prepare expected column names
occ2.columns = ['ds', 'y']
#occ2['ds']= to_datetime(occ2['ds'])
# define the model
model = Prophet(interval_width=0.95)
# fit the model
model.fit(occ2)

# %%
future = model.make_future_dataframe(periods=90, freq='D')
forecast = model.predict(future)
forecast.head()

# %%
forecast.shape

# %%
forecast.ds.max()

# %%
plot2 = model.plot(forecast, figsize=(15, 10))

# %%
print(occupancy.DATE.min())
print(occupancy.DATE.max())

# %%
plot5 = model.plot_components(forecast)

# %%
# Plotting in plotly
from fbprophet.plot import plot_plotly, plot_components_plotly
import plotly.offline as py
py.init_notebook_mode()

# %%
fig7 = plot_plotly(model, forecast)
py.iplot(fig7)

# %% [markdown]
# ## Multivariate?

# %%
df2.to_csv('datasets/Dataset_non_cancelled.csv', index=False)

# %%
occupancy

# %%
occ_heat

# %%
nuevogrupo = occ_heat.groupby('day_of_week')['Nights'].sum().reset_index()
nuevogrupo

# %%
df2.head()

# %%
chicosnac = df2.groupby('Country')['Children'].sum().reset_index()
chicosnac

# %%
ax = sns.countplot(y="Country", data=chicosnac ,
                   palette='Accent' )
sns.set(rc = {'figure.figsize':(10,8)})

# %%
ADR_wd2

# %%
occ_heat

# %%
def f(x):
    d = {}
    d['ttl_net_per_nt_sum'] = x['ttl_net_per_nt'].sum()
    d['nights_sum'] = x['Nights'].sum(), 
    d['nights_count'] = x['Nights'].count()
    return pd.Series(d, index=['ttl_net_per_nt_sum', 'nights_sum', 'nights_count'])

ADR_wd3 = occ_heat.groupby('day_of_week').apply(f)
ADR_wd3#.unstack(level=0).reset_index()

# %%
ADR_wd3['nights_sum'] = ADR_wd3['nights_sum'].apply(str)
ADR_wd3['nights_sum'] = ADR_wd3['nights_sum'].str[1:-2].apply(int)
ADR_wd3['nts_sum_div_nts_count'] = ADR_wd3['nights_sum']/(ADR_wd3['nights_count']*45)*100

# %%
ADR_wd3

# %%
occ_heat.head()

# %%
ADR_wd2 = occ_heat.groupby('day_of_week').agg({'ttl_net_per_nt':'sum', 
                                               'Nights' :  'sum', 
                                               'ADR':'mean'
                                              }).reset_index()
#ADR_wd2['ADR'] =  ADR_wd2['ttl_net_per_nt'] / ADR_wd2['Nights']
#ADR_wd2.rename(columns = {'Nights':'Av_q_nights'}, inplace=True)
ADR_wd2

# %%
ADR_wd2.Nights[0]

# %%
occ_heat.groupby('day_of_week')['Nights'].sum()

# %%
#ADR_wd = occ_heat.groupby('day_of_week')['ADR'].mean().reset_index()
#ADR_wd

# %%
ax = sns.barplot(x="day_of_week", y='ADR', data=ADR_wd2 , order=['Monday', 'Tuesday', 'Wednesday', 
                                                          'Thursday', 'Friday', 'Saturday', 'Sunday'],
                   palette='Accent' )

sns.set(rc = {'figure.figsize':(10,8)})

# %% [raw]
# # twin object for two different y-axis on the sample plot
# ax2=ax.twinx()
# # make a plot with different y-axis using second axis object
# ax2.plot(gapminder_us.year, gapminder_us["gdpPercap"],color="blue",marker="o")
# ax2.set_ylabel("gdpPercap",color="blue",fontsize=14)
# plt.show()
# # save the plot as a file
# fig.savefig('two_different_y_axis_for_single_python_plot_with_twinx.jpg',
#             format='jpeg',
#             dpi=100,
#             bbox_inches='tight')

# %%
ADR_wd2.to_csv('datasets/ADR_wd2.csv')

# %% [raw]
# # line plot talking women by season
# plt.plot(ADR_wd2.day_of_week.unique(), (ADR_wd2.ADR), label='ADR')
# plt.plot(ADR_wd2.day_of_week.unique(), (ADR_wd2.occ_rate), label='Occ_rate')
#
# plt.xlabel('Season')
# plt.ylabel('Number of Words')
# plt.title('"Friends" Women, Number of Words Spoken per Season')
# plt.legend()
# plt.show()

# %% [raw]
# import numpy as np
# import matplotlib.pyplot as plt
#
#
#
# fig, ax1 = plt.subplots()
#
#
# ax1.set_xlabel('Weekday')
# ax1.set_ylabel('ADR')
# ax1.bar(ADR_wd2.day_of_week.unique(), ADR_wd2.ADR, color='darkorchid' )
# ax1.tick_params(axis='y', labelcolor='darkorchid')
# ax1.set_ylim(0, 100)
#
#
# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
#
#
# ax2.set_ylabel('Occ_rate')  # we already handled the x-label with ax1
# ax2.plot(ADR_wd2.day_of_week.unique(), ADR_wd2.occ_rate, color='black')
# ax2.tick_params(axis='y')
# ax2.set_ylim(50, 15)
#
#
# fig.tight_layout()
# fig.suptitle('This is a somewhat long figure title')
# # otherwise the right y-label is slightly clipped
# plt.show()

# %%
ADR_wd3 = ADR_wd3.reset_index()
ADR_wd3

# %%
days_wk_num = [4,0,5,6,3,1,2]
ADR_wd2['days_wk_num'] = days_wk_num
ADR_wd2

# %%
ADR_wd2.sort_values(by='days_wk_num', inplace=True)
ADR_wd2.reset_index(drop=True, inplace=True)

# %%
ADR_wd3 = ADR_wd3.reset_index()
ADR_wd3

# %%
plt.figure(figsize=(15, 8))
ax = sns.barplot(x='day_of_week', y='nts_sum_div_nts_count', data=ADR_wd3, color= 'lightsteelblue',
                 order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
                )
ax.set_xlabel('Day of the Week', size=14)
ax.set_ylabel('Occupancy Rate')
#ax.yaxis.set_major_formatter(PercentFormatter(1))

ax2 = ax.twinx()
sns.lineplot(x='day_of_week', y='ADR', data=ADR_wd2, marker='o', color='crimson'  )#, lw=3, ax=ax2)
#ax2.sns.color_palette("Blues", as_cmap=True)
ax2.set(ylim=(0, 60))
ax2.yaxis.label.set_color('red')
ax2.set_ylabel('Average Daily Rate (ADR)')
ax2.tick_params(axis='y', colors='red')

plt.title('ADR and Occupancy : Days of the Week', size=20)
plt.show()

# %%
ADR_wd3
